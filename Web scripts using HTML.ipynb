# %% [markdown]
# # מטלת סיכום חלק 1

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import pandas as pd

# %%
def get_cars(keywords):
    car_list = list()
    import requests
    from bs4 import BeautifulSoup
    url = "https://www.ad.co.il/car?keyword=" + keywords
    response = requests.get(url)
    if not response.status_code == 200:
        print ("not 200")
        return None
    try:
        results_page = BeautifulSoup(response.content, 'html.parser')
        cars = results_page.find_all('div',{'class':'card-body p-md-3'})
        for car in cars:
            car_link = "https://www.ad.co.il" + car.find('a').get('href')
            car_name = car.find('a').get_text()
            
            if keywords in car_name:
                car_list.append((car_link)) 
        return car_list
    except:
        return None

# %%
get_cars("אלפא רומיאו")
# Out:
# ['https://www.ad.co.il/ad/16027552',
#  'https://www.ad.co.il/ad/15941395',
#  'https://www.ad.co.il/ad/16108801',
#  'https://www.ad.co.il/ad/14706603',
#  'https://www.ad.co.il/ad/14671215',
#  'https://www.ad.co.il/ad/14655354',
#  'https://www.ad.co.il/ad/14530834',
#  'https://www.ad.co.il/ad/14500119',
#  'https://www.ad.co.il/ad/14198876',
#  'https://www.ad.co.il/ad/14108320',
#  'https://www.ad.co.il/ad/13939340',
#  'https://www.ad.co.il/ad/13815766',
#  'https://www.ad.co.il/ad/13742668',
#  'https://www.ad.co.il/ad/15885588',
#  'https://www.ad.co.il/ad/15761625',
#  'https://www.ad.co.il/ad/14439006',
#  'https://www.ad.co.il/ad/14348853',
#  'https://www.ad.co.il/ad/15761645']

# %%
def preprocess_date_string(date_str):
    # Check if the input is a valid string or NaT
    if pd.isna(date_str):
        return "nan"
        
    # Check for slash or hyphen delimiters
    if '/' in date_str:
        parts = date_str.split('/')
    elif '-' in date_str:
        parts = date_str.split('-')
    else:
        return np.nan
    
    # Ensure parts are in the form of [YY, MM, DD] or [YY, MM]
    if len(parts) == 2:  # Format: YY/MM or YY-MM
        month, year = parts
        day = '01'  # Default day to the first of the month
    elif len(parts) == 3:  # Format: YY/MM/DD or YY-MM-DD
        day, month, year = parts
    else:
        return np.nan
    
    # Ensure all parts have leading zeros if necessary
    year = year.zfill(2)
    month = month.zfill(2)
    day = day.zfill(2)
    
    # Assume any two-digit year 'YY' represents '20YY'
    if len(year) == 2:
        year = '20' + year
    
    return f'{year}-{month}-{day}'

def days_until(date):
    today = datetime.today()
    delta = date - today
    return delta.days

# %%
def get_car_info(car_link):
    car_dict = {}
    try:
        response = requests.get(car_link)
        if response.status_code != 200:
            return {"error": "Failed to retrieve page"}
        
        result_page = BeautifulSoup(response.content, 'html.parser')
        meta_element = result_page.find('meta', itemprop='position', content='3')
        if meta_element:
            li_element = meta_element.find_parent('li', class_='breadcrumb-item')
            if li_element:
                item_name = li_element.find('span', itemprop='name')
                if item_name:
                    name = item_name.get_text()
                    car_dict["manufactor"] = name
        
        table = result_page.find('table', {'class': 'table table-sm mb-4'})
        if table:
            tbody = table.find('tbody')
            if tbody:
                for tr in tbody.find_all("tr"):
                    td = tr.find_all('td')
                    if len(td) >= 2:
                        key = td[0].get_text().strip()
                        value = td[1].get_text().strip()
                        car_dict[key] = value
        
        pictures = result_page.find_all('div', {'class': 'justify-content-center px-1'})
        car_dict['Pic_num'] = len(pictures)
        
        model_and_price = result_page.find_all('h2', {'class': 'card-title'})
        if len(model_and_price) >= 2:
            car_dict['Price'] = model_and_price[1].get_text().strip().replace('₪', '').replace(',', '').replace(' ', '')
            car_dict['model'] = model_and_price[0].get_text().strip()
        
        Repub_date_and_Cre_date = result_page.find_all('div', {'class': 'px-3'})
        if len(Repub_date_and_Cre_date) >= 2:
            cre_date = Repub_date_and_Cre_date[0].get_text().split()
            Repub_date = Repub_date_and_Cre_date[1].get_text().split()
            if len(cre_date) >= 3:
                car_dict['Cre_date'] = cre_date[2]
            if len(Repub_date) >= 4:
                car_dict['Repub_date'] = Repub_date[3]
        description_tag = result_page.find('p', {'class': 'text-word-break'})
        if description_tag:
            car_dict['description'] = description_tag.get_text().strip()
        
        if 'שנה' in car_dict:
            car_dict['שנה'] = int(car_dict['שנה'])
        if 'יד' in car_dict:
            car_dict['יד'] = int(car_dict['יד'])
        if 'נפח' in car_dict:
            car_dict['נפח'] = int(''.join(filter(str.isdigit, car_dict['נפח'])))
        if 'Price' in car_dict:
            car_dict['Price'] = float(car_dict['Price'])
        if 'Cre_date' in car_dict:
            car_dict['Cre_date'] = datetime.strptime(car_dict['Cre_date'], '%d/%m/%Y').date()
        if 'Repub_date' in car_dict:
            car_dict['Repub_date'] = datetime.strptime(car_dict['Repub_date'], '%d/%m/%Y').date()
        if 'ק"מ' in car_dict:
            car_dict['ק"מ'] = int(car_dict['ק"מ'].replace(',', ''))
        if 'טסט עד' in car_dict:
            test_date_str = preprocess_date_string(car_dict['טסט עד'])
            test_date = pd.to_datetime(test_date_str, errors='coerce')
            if not pd.isna(test_date):
                car_dict['days_until_test'] = int(days_until(test_date))
            del car_dict['טסט עד']
        
        return car_dict
    
    except Exception as e:
        print(f"An error occurred: {e}")
        return {"error": str(e)}

# %%
get_car_info('https://www.ad.co.il/ad/16108801')
# Out:
# {'manufactor': 'אלפא רומיאו',
#  'שנה': 2023,
#  'יד': 1,
#  'ת. הילוכים': 'אוטומטית',
#  'נפח': 2000,
#  'סוג מנוע': 'בנזין',
#  'ק"מ': 5000,
#  'צבע': 'לבן',
#  'בעלות קודמת': 'פרטית',
#  'בעלות נוכחית': 'פרטית',
#  'אזור': 'גליל ועמקים',
#  'עיר': 'נצרת',
#  'Pic_num': 6,
#  'Price': 250000.0,
#  'model': "אלפא רומיאו ג'וליה",
#  'Cre_date': datetime.date(2024, 2, 25),
#  'Repub_date': datetime.date(2024, 2, 25),
#  'description': 'רכב הכי מצוין',
#  'days_until_test': 210}

# %%
def get_all_cars(keywords):
    results = list()
    all_cars = get_cars(keywords)
    for car in all_cars:
        x = get_car_info(car)
        results.append(x)
    return results

# %%
alfa_cars=get_all_cars("אלפא רומיאו")

# %%
alfa_cars
# Out:
# [{'manufactor': 'אלפא רומיאו',
#   'שנה': 2015,
#   'יד': 3,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 1800,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 180000,
#   'צבע': 'שחור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'Pic_num': 10,
#   'Price': 80000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2023, 11, 23),
#   'Repub_date': datetime.date(2023, 11, 23),
#   'description': 'אלפא רומיאו ג׳ולייטה תלתן ירוק שנת 2015 הכי מיוחדת בארץ.\nלאנץ אדישן (1/999)\nגמיש מעט\nאחרי יישור קו: קלאצ׳ים חדשים, משאבת מים, טיימינג, ציריות, תושבות, בושינגים למשולשים ועוד… האוטו מכנית מושלם. כל הרכב עיטוף PPF בשווי 20K₪. הרכב משופר עומד על בערך 350 כוח סוס, סטינג 2 +, קוילאוברים KW V2, דיפרנציאל מוגבל החלקה LSD, קיט יניקה GSR, רפידות, צלחות, אינטרקולר מוגדל לטורבו, מוטות מייצבים קדמיים ואחוריים, כיסאות באקט, חלקי קרבון, תאורה ראשית טורבו לד לבן, מערכת מולטימדיה של pioneer עם Car Play אלחוטי, ועוד המון תוספות….'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2017,
#   'יד': 3,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 2000,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 93000,
#   'צבע': 'אדום מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'שפרעם',
#   'Pic_num': 4,
#   'Price': 99.0,
#   'model': "אלפא רומיאו ג'וליה",
#   'Cre_date': datetime.date(2023, 9, 27),
#   'Repub_date': datetime.date(2023, 9, 27),
#   'description': 'שמורה בקנאות טיפולים בחברה \nחלונות שחורים ספויילר אחורי \nיפהפיה ללא שיפורים'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2023,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 2000,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 5000,
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'נצרת',
#   'Pic_num': 6,
#   'Price': 250000.0,
#   'model': "אלפא רומיאו ג'וליה",
#   'Cre_date': datetime.date(2024, 2, 25),
#   'Repub_date': datetime.date(2024, 2, 25),
#   'description': 'רכב הכי מצוין',
#   'days_until_test': 210},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2015,
#   'יד': 3,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 1800,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 147000,
#   'צבע': 'אדום',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'Pic_num': 6,
#   'Price': 70000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2022, 11, 7),
#   'Repub_date': datetime.date(2022, 11, 7),
#   'description': 'אלפא רומיאו גולייטה תלתן ירוק אדומה\nQV Monza רמת גימור\nמנוע המספק 240 כ"ס עם גיר דואל קלאטץ\nרכב חוויה בכל רמה אפשרית, מפנק ונוח מאוד, וגם מספק הנאה של רכב ספורט לכל הדעות\nאחרי טיפול, טורבו חדש לפני שלושה חודשים וטיפול טיימינג\nמבקש 70,000 ש"ח, גמיש מעט לרציניים ליד הרכב\n\nאורי 0504456566'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2011,
#   'יד': 5,
#   'ת. הילוכים': 'ידנית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 163000,
#   'צבע': 'לבן שנהב',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'רחובות',
#   'Pic_num': 6,
#   'Price': 46000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2022, 10, 31),
#   'Repub_date': datetime.date(2022, 10, 31),
#   'description': 'רכב שמור מאוד דגם מילאנו עם גג פנורמי\nידני בין הבודדות שיש\n0 תקלות\nעובר טיפול כל 8 אלף \nיש קלאץ׳ חדש'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2015,
#   'יד': 3,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 14000,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 96000,
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'Pic_num': 1,
#   'Price': 60000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2022, 10, 27),
#   'Repub_date': datetime.date(2022, 10, 27),
#   'description': "אלפא רומיו ג'ולייטה\r\nרכב עבר רק במשפחה\r\n - אוטומט שנת 2015\r\n - יד 03 (בפועל 2)\r\n - ק״מ 96.000\r\n - טסט 5/23 \r\n מטופלת ומתוחזקת בקפידה עם קבלות + עברה טיפול גדול לפני 4 חודשים:\r\n- טיימינג כולל תרמוסטט, 3 תושבות מנוע, פלגים, מצערת – הכל מקורי\r\n- צלחות מאווררות ורפידות BREMBO\r\n- מצבר חדש"},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2010,
#   'יד': 3,
#   'ת. הילוכים': 'ידנית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 141000,
#   'אזור': 'עכו - נהריה',
#   'עיר': 'כפר יאסיף',
#   'Pic_num': 1,
#   'Price': 32000.0,
#   'model': 'אלפא רומיאו מיטו',
#   'Cre_date': datetime.date(2022, 9, 27),
#   'Repub_date': datetime.date(2022, 9, 27),
#   'description': 'רכב במצב תצוגה אחרי טיפול 1.4 טורבו 155 כ״ס מנוע t-jet &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; האוטו במצב מצוין תושבות מנוע וגיר חדשים, 4 צמיגים חדשים, פילטר אינבוקס k&amp;n, אגזוז על שלט, השחרת חלונות בחלק האחורי, הגג בפנים בצבע שחור, האוטו עבר טיפול שמנים ושמן גיר לפני שבוע, טיימינג ומשאבת מים לפני חודש, בולמי קוני כתום שמשפרים את הניסעה, צינור יניקה מסילקון אכותי, דיפיוזר אחורי שתי יצאות, מדחס מזגן חדש, מערכת מולטימדיה אנדרואיד, racechip s שמוסיף עוד 20 כ״ס.\r\nאוטו במצב תצוגה כל הקודם זוכה.'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2011,
#   'יד': 4,
#   'ת. הילוכים': 'ידנית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 180,
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'גן יבנה',
#   'Pic_num': 1,
#   'Price': 15000.0,
#   'model': 'אלפא רומיאו מיטו',
#   'Cre_date': datetime.date(2022, 9, 20),
#   'Repub_date': datetime.date(2022, 9, 20),
#   'description': 'דגם ספורט ידני 6 הילוכים\r\nמולטימדיה הרכב במצב חדש לרצינים בלבד'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2014,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'Pic_num': 1,
#   'Price': 50000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2022, 7, 21),
#   'Repub_date': datetime.date(2022, 7, 21),
#   'description': 'פרטית, שמורה מאד\r\nטיפול כל 8000, טסט 3/23\r\n160000 קמ אחרי ציפוי ננו'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2011,
#   'יד': 2,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 3000,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 140000,
#   'אזור': 'גליל ועמקים',
#   'עיר': 'נצרת עילית',
#   'Pic_num': 1,
#   'Price': 36000.0,
#   'model': 'אלפא רומיאו 159',
#   'Cre_date': datetime.date(2022, 7, 2),
#   'Repub_date': datetime.date(2022, 7, 2),
#   'description': 'על הרכב\r\n159 2.2 סלסלפיד רמת גימור TI . אחרי קלאץ, טסט לשנה, עבר חלק. הוחלף החודש בולמים קדמיים, מוטות קישור למוט מייצב, צירייה ימין+שמול , מחזיר שמן צירייה, שמן גיר, טיפול שמן ופילטר שמן, ניקוי מצערת, ניקוי pcv, צינור שמן הגה ותושבת מנוע עליונה. הרכב במצב מצויין'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2012,
#   'יד': 3,
#   'ת. הילוכים': 'ידנית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 122000,
#   'צבע': 'אפור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'Pic_num': 9,
#   'Price': 24999.0,
#   'model': 'אלפא רומיאו מיטו / MITO',
#   'Cre_date': datetime.date(2022, 6, 3),
#   'Repub_date': datetime.date(2022, 6, 3),
#   'description': '⚜️למכירה⚜️\n⚜️אלפא רומיאו מיטו⚜️\n⚜️שנת 2012\n⚜️מנוע 1400 \n⚜️יד 3 (02 ברישיון)\n⚜️ידנית⚜️\n⚜️עם 118 אלף קמ\n⚜️טסט לשנה\n⚜️נהג יחיד\nשמורה מאוד\nעברה טיפול פילטרים ושמן\nללא תאונות\nגמיש ליד הרכב'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2018,
#   'יד': 1,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 1742,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 30400,
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'רמת גן',
#   'Pic_num': 1,
#   'Price': 150000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2022, 5, 16),
#   'Repub_date': datetime.date(2022, 5, 16),
#   'description': 'ג\'ולייטה ולוצ\'ה (תלתן ) יד ראשונה, סטוק, 240 כ"ס 1.7T ספורט מדהימה\r\nנקי ושמור מאד\r\n30,000 ק"מ בלבד\r\nנהג יחיד'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2010,
#   'יד': 3,
#   'ת. הילוכים': 'ידנית',
#   'נפח': 1800,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 150000,
#   'צבע': 'שחור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'Pic_num': 6,
#   'Price': 46000.0,
#   'model': 'אלפא רומיאו 159',
#   'Cre_date': datetime.date(2022, 5, 1),
#   'Repub_date': datetime.date(2022, 5, 11),
#   'description': '\u200fTBI 1.8 טורבו \n200 כ"ס ידני קלסיקו\n150 אלף ק"מ\nיד 3\nבשנה אחרונה עברה טיפול אצל מיכאל כולל החלפת צנרת הגה כוח ולפני כן טופלה אצל איציק\nבנוסף הוחלפו צלחות ורפידות Brembo\nצמיגים חדשים\nמטופלת ומתוחזקת נמכרת עקב אי שימוש \n₪46,000\nלפרטים נוספים 0528488250'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2016,
#   'יד': 6,
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': 1400,
#   'סוג מנוע': 'דיזל',
#   'ק"מ': 67777,
#   'צבע': 'זהב',
#   'בעלות קודמת': 'השכרה',
#   'בעלות נוכחית': 'חברה',
#   'אזור': 'תל אביב',
#   'עיר': 'תל אביב יפו',
#   'Pic_num': 0,
#   'Price': 6666666.0,
#   'model': 'אלפא רומיאו 159',
#   'Cre_date': datetime.date(2023, 8, 17),
#   'Repub_date': datetime.date(2023, 8, 17),
#   'description': 'לחברת "דרושים אקספרסס" , דרושים דרושות!!! עקב הביקוש הרב ממשיכים לגייס!! דרושים לעבודה בהקלדת נתונים וקלדנות מהטלפון או מהמחשב ללא ניסיון! לפניות צרו קשר בוואטספ 050-233-2971 , .'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2010,
#   'יד': 4,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 2200,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 190000,
#   'צבע': 'אפור עכבר',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'נצרת',
#   'Pic_num': 0,
#   'Price': 10000.0,
#   'model': 'אלפא רומיאו 159',
#   'Cre_date': datetime.date(2023, 6, 10),
#   'Repub_date': datetime.date(2023, 6, 10)},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2011,
#   'יד': 3,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 156,
#   'אזור': 'תל אביב',
#   'עיר': 'תל אביב יפו',
#   'Pic_num': 0,
#   'Price': 25000.0,
#   'model': 'אלפא רומיאו מיטו',
#   'Cre_date': datetime.date(2022, 9, 7),
#   'Repub_date': datetime.date(2022, 9, 7),
#   'description': 'אלפה מיטו 2011 למכירה רכב מדהים .\r\nצבע שחור נוסע מצויין טסט 5 חודשים\r\nמוכר עקב קבלת רכב מהעבודה . דורש 25,000 גמיש מעט הליד הרכב. לרצנים בלבד. מנוע 1.4 טורבו &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; יש לרכב מולטמדיה חדשה פלוס מצלמת רוורס'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2013,
#   'יד': 4,
#   'ת. הילוכים': 'ידנית',
#   'נפח': 1400,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 160000,
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'Pic_num': 0,
#   'Price': 45000.0,
#   'model': "אלפא רומיאו ג'ולייטה",
#   'Cre_date': datetime.date(2022, 8, 18),
#   'Repub_date': datetime.date(2022, 8, 18),
#   'description': 'פרטית \r\nמכונית יפיפיה ללא שום תאונות ואו תיקון צבע כל שהוא.\r\nידנית ,שישה הילוכים.'},
#  {'manufactor': 'אלפא רומיאו',
#   'שנה': 2010,
#   'יד': 4,
#   'ת. הילוכים': 'רובוטית',
#   'נפח': 2200,
#   'סוג מנוע': 'בנזין',
#   'ק"מ': 190000,
#   'צבע': 'אפור מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'נצרת',
#   'Pic_num': 0,
#   'Price': 10000.0,
#   'model': 'אלפא רומיאו 159',
#   'Cre_date': datetime.date(2023, 6, 10),
#   'Repub_date': datetime.date(2023, 6, 10)}]

# %%
import pandas as pd
df=pd.DataFrame(alfa_cars)

# %%
df = df.rename(columns={'שנה': 'Year', 'יד': 'Hand','ת. הילוכים': 'Gear', 'נפח': 'Engine_capacity','סוג מנוע': 'Engine_type', 'ק"מ': 'Km','טסט עד': 'Test ', 'צבע': 'Color','עיר': 'City', 'אזור': 'Area','בעלות נוכחית':'Prev_ownership','בעלות קודמת':'Curr_ownership'})

# %%
df['Cre_date'] = pd.to_datetime(df['Cre_date'], dayfirst=True)
df['Gear'] = pd.Categorical(df['Gear'])
df['Km'] = pd.to_numeric(df['Km'], errors='coerce').fillna(0).astype(int)
df['Engine_type'] = pd.Categorical(df['Engine_type'])
df['Curr_ownership'] = pd.Categorical(df['Curr_ownership'])
df['Prev_ownership'] = pd.Categorical(df['Prev_ownership'])
df['Area'] = df['Area'].astype(str)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce').fillna(0).astype(float)
df['Repub_date'] = pd.to_datetime(df['Repub_date'], dayfirst=True)
df['days_until_test'] = pd.to_numeric(df['days_until_test'], errors='coerce').replace(0, np.nan).astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manufactor       18 non-null     object
#  1   Year             18 non-null     int64
#  2   Hand             18 non-null     int64
#  3   Gear             18 non-null     category
#  4   Engine_capacity  18 non-null     int64
#  5   Engine_type      18 non-null     category
#  6   Km               18 non-null     int32
#  7   Color            10 non-null     object
#  8   Curr_ownership   10 non-null     category
#  9   Prev_ownership   10 non-null     category
#  10  Area             18 non-null     object
#  11  City             18 non-null     object
#  12  Pic_num          18 non-null     int64
#  13  Price            18 non-null     float64
#  14  model            18 non-null     object
#  15  Cre_date         18 non-null     datetime64[ns]
#  16  Repub_date       18 non-null     datetime64[ns]
#  17  description      16 non-null     object
#  18  days_until_test  1 non-null      Int64
# dtypes: Int64(1), category(4), datetime64[ns](2), float64(1), int32(1), int64(4), object(6)
# memory usage: 2.7+ KB

# %%
df
# Out:
#      manufactor  Year  Hand      Gear  Engine_capacity Engine_type      Km  \
# 0   אלפא רומיאו  2015     3  אוטומטית             1800       בנזין  180000
# 1   אלפא רומיאו  2017     3  אוטומטית             2000       בנזין   93000
# 2   אלפא רומיאו  2023     1  אוטומטית             2000       בנזין    5000
# 3   אלפא רומיאו  2015     3  אוטומטית             1800       בנזין  147000
# 4   אלפא רומיאו  2011     5     ידנית             1400       בנזין  163000
# 5   אלפא רומיאו  2015     3   רובוטית            14000       בנזין   96000
# 6   אלפא רומיאו  2010     3     ידנית             1400       בנזין  141000
# 7   אלפא רומיאו  2011     4     ידנית             1400       בנזין     180
# 8   אלפא רומיאו  2014     1  אוטומטית             1400       בנזין       0
# 9   אלפא רומיאו  2011     2   רובוטית             3000       בנזין  140000
# 10  אלפא רומיאו  2012     3     ידנית             1400       בנזין  122000
# 11  אלפא רומיאו  2018     1  אוטומטית             1742       בנזין   30400
# 12  אלפא רומיאו  2010     3     ידנית             1800       בנזין  150000
# 13  אלפא רומיאו  2016     6  אוטומטית             1400        דיזל   67777
# 14  אלפא רומיאו  2010     4   רובוטית             2200       בנזין  190000
# 15  אלפא רומיאו  2011     3   רובוטית             1400       בנזין     156
# 16  אלפא רומיאו  2013     4     ידנית             1400       בנזין  160000
# 17  אלפא רומיאו  2010     4   רובוטית             2200       בנזין  190000
#
#          Color Curr_ownership Prev_ownership               Area  \
# 0         שחור          פרטית          פרטית    חיפה וחוף הכרמל
# 1   אדום מטאלי          פרטית          פרטית        גליל ועמקים
# 2          לבן          פרטית          פרטית        גליל ועמקים
# 3         אדום          פרטית          פרטית    באר שבע והסביבה
# 4     לבן שנהב          פרטית          פרטית  נס ציונה - רחובות
# 5          NaN            NaN            NaN    חיפה וחוף הכרמל
# 6          NaN            NaN            NaN        עכו - נהריה
# 7          NaN            NaN            NaN     אשדוד - אשקלון
# 8          NaN            NaN            NaN    מודיעין והסביבה
# 9          NaN            NaN            NaN        גליל ועמקים
# 10        אפור          פרטית          פרטית    באר שבע והסביבה
# 11         NaN            NaN            NaN   רמת גן - גבעתיים
# 12        שחור          פרטית          פרטית     ראשל"צ והסביבה
# 13         זהב          השכרה           חברה            תל אביב
# 14   אפור עכבר          פרטית          פרטית        גליל ועמקים
# 15         NaN            NaN            NaN            תל אביב
# 16         NaN            NaN            NaN    חיפה וחוף הכרמל
# 17  אפור מטאלי          פרטית          פרטית        גליל ועמקים
#
#                   City  Pic_num      Price                    model  \
# 0                 חיפה       10    80000.0     אלפא רומיאו ג'ולייטה
# 1                שפרעם        4       99.0       אלפא רומיאו ג'וליה
# 2                 נצרת        6   250000.0       אלפא רומיאו ג'וליה
# 3              באר שבע        6    70000.0     אלפא רומיאו ג'ולייטה
# 4               רחובות        6    46000.0     אלפא רומיאו ג'ולייטה
# 5                 חיפה        1    60000.0     אלפא רומיאו ג'ולייטה
# 6            כפר יאסיף        1    32000.0         אלפא רומיאו מיטו
# 7              גן יבנה        1    15000.0         אלפא רומיאו מיטו
# 8   מודיעין מכבים רעות        1    50000.0     אלפא רומיאו ג'ולייטה
# 9           נצרת עילית        1    36000.0          אלפא רומיאו 159
# 10             באר שבע        9    24999.0  אלפא רומיאו מיטו / MITO
# 11              רמת גן        1   150000.0     אלפא רומיאו ג'ולייטה
# 12         ראשון לציון        6    46000.0          אלפא רומיאו 159
# 13         תל אביב יפו        0  6666666.0          אלפא רומיאו 159
# 14                נצרת        0    10000.0          אלפא רומיאו 159
# 15         תל אביב יפו        0    25000.0         אלפא רומיאו מיטו
# 16                חיפה        0    45000.0     אלפא רומיאו ג'ולייטה
# 17                נצרת        0    10000.0          אלפא רומיאו 159
#
#      Cre_date Repub_date                                        description  \
# 0  2023-11-23 2023-11-23  אלפא רומיאו ג׳ולייטה תלתן ירוק שנת 2015 הכי מי...
# 1  2023-09-27 2023-09-27  שמורה בקנאות טיפולים בחברה \nחלונות שחורים ספו...
# 2  2024-02-25 2024-02-25                                      רכב הכי מצוין
# 3  2022-11-07 2022-11-07  אלפא רומיאו גולייטה תלתן ירוק אדומה\nQV Monza ...
# 4  2022-10-31 2022-10-31  רכב שמור מאוד דגם מילאנו עם גג פנורמי\nידני בי...
# 5  2022-10-27 2022-10-27  אלפא רומיו ג'ולייטה\r\nרכב עבר רק במשפחה\r\n -...
# 6  2022-09-27 2022-09-27  רכב במצב תצוגה אחרי טיפול 1.4 טורבו 155 כ״ס מנ...
# 7  2022-09-20 2022-09-20  דגם ספורט ידני 6 הילוכים\r\nמולטימדיה הרכב במצ...
# 8  2022-07-21 2022-07-21  פרטית, שמורה מאד\r\nטיפול כל 8000, טסט 3/23\r\...
# 9  2022-07-02 2022-07-02  על הרכב\r\n159 2.2 סלסלפיד רמת גימור TI . אחרי...
# 10 2022-06-03 2022-06-03  ⚜️למכירה⚜️\n⚜️אלפא רומיאו מיטו⚜️\n⚜️שנת 2012\n...
# 11 2022-05-16 2022-05-16  ג'ולייטה ולוצ'ה (תלתן ) יד ראשונה, סטוק, 240 כ...
# 12 2022-05-01 2022-05-11  ‏TBI 1.8 טורבו \n200 כ"ס ידני קלסיקו\n150 אלף ...
# 13 2023-08-17 2023-08-17  לחברת "דרושים אקספרסס" , דרושים דרושות!!! עקב ...
# 14 2023-06-10 2023-06-10                                                NaN
# 15 2022-09-07 2022-09-07  אלפה מיטו 2011 למכירה רכב מדהים .\r\nצבע שחור ...
# 16 2022-08-18 2022-08-18  פרטית \r\nמכונית יפיפיה ללא שום תאונות ואו תיק...
# 17 2023-06-10 2023-06-10                                                NaN
#
#     days_until_test
# 0              <NA>
# 1              <NA>
# 2               210
# 3              <NA>
# 4              <NA>
# 5              <NA>
# 6              <NA>
# 7              <NA>
# 8              <NA>
# 9              <NA>
# 10             <NA>
# 11             <NA>
# 12             <NA>
# 13             <NA>
# 14             <NA>
# 15             <NA>
# 16             <NA>
# 17             <NA>

# %%
csv_file_path = 'car_info.csv'
df.to_csv(csv_file_path, index=False, encoding='utf-8-sig', date_format='%Y-%m-%d')

print(f"DataFrame has been saved to {csv_file_path}")

from IPython.display import FileLink
FileLink(csv_file_path)
# Out:
# DataFrame has been saved to car_info.csv
# C:\Users\itayh\Tasks\car_info.csv
